# %%
import sys
import os
sys.path.append(os.path.abspath('../downloadFiles'))
from downloadFiles import getMachine

# %% [markdown]
# ### List of transformers:

# %% [markdown]
# T16 (Let's call it 16): 250MVA transformer in ICL; machine_id: 60337dd09168b8000193bf07
# T7 (Let's call it 7 from now on): 40MVA transformer in ICL; machine_id: 6033827891acc600014851ba
# T8 (Let's call it 8 from now on): 40MVA transformer in ICL; machine_id: 6033829291acc600014851ce
# 532 (Let's call it 532 from now on :) ): 60MVA transformer in ICL; machine_id: 60583f645693e10001ae220a
# 533 (Let's call it 533 from now on :) ): 90MVA transformer in ICL; machine_id: 60583fc9076ce800017ea8e9
# 534 (Let's call it 534 from now on :) ): 100MVA transformer in ICL; machine_id: 60583fed076ce800017ea90d
# 25/5 (Let's call it 25 from now on ): 5MVA transformer in ICL; machine_id: 60584078076ce800017ea96f
# 29/5 (Let's call it 25 from now on ): 5MVA transformer in ICL; machine_id: 605b28a6b622d20001d910da
# 21/5 (Let's call it 21 from now on ): 5MVA transformer in ICL; machine_id: 608a71fd041d100001acf1ab
# TRF01 (Let's call it 1): 125MVA transformer in Bazan; machine_id: 60e427667f4fc200019e006a

# %%
machineIDs = {
    'T16': '60337dd09168b8000193bf07',
    'T7': '6033827891acc600014851ba',
    'T8': '6033829291acc600014851ce',
    '532': '60583f645693e10001ae220a',
    '533': '60583fc9076ce800017ea8e9',
    '534': '60583fed076ce800017ea90d',
    '25_5': '60584078076ce800017ea96f',
    '29_5': '605b28a6b622d20001d910da',
    '21_5': '608a71fd041d100001acf1ab',
    'TRF01': '60e427667f4fc200019e006a',
}

# %%
for transromer, machineID in machineIDs.items():
    print(transromer)
    getMachine(
        machine_id=machineID,
        timeBeginSTR='2020-12-18 0:0:0',
        dHors=24*30*12*5,
        dest_dir='/Users/gkogan/myRepos/myGit/' + transromer,
    )
    break
# Out:
# ('T16', '60337dd09168b8000193bf07')
# ('T7', '6033827891acc600014851ba')
# ('T8', '6033829291acc600014851ce')
# ('532', '60583f645693e10001ae220a')
# ('533', '60583fc9076ce800017ea8e9')
# ('534', '60583fed076ce800017ea90d')
# ('25_5', '60584078076ce800017ea96f')
# ('29_5', '605b28a6b622d20001d910da')
# ('21_5', '608a71fd041d100001acf1ab')
# ('TRF01', '60e427667f4fc200019e006a')
